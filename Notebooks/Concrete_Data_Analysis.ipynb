# %%
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# # Scalars, Vectors, Matrices, and Tensors
#
# **Scalar (0D):**
# $$
# x = 5
# $$
#
# **Vector (1D):**
# $$
# \mathbf{x} =
# \begin{bmatrix}
# 1 \\
# 2 \\
# 3
# \end{bmatrix}
# $$
#
# **Matrix (2D):**
# $$
# \mathbf{X} =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix}
# $$
#
# **Tensor (3D Example):**
# Think of this as multiple matrices stacked together:
# $$
# \mathcal{T} =
# \begin{bmatrix}
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4
# \end{bmatrix},
# \begin{bmatrix}
# 5 & 6 \\
# 7 & 8
# \end{bmatrix}
# \end{bmatrix}
# $$

# %%
# Scalar = 0D Tensor
scalar = torch.tensor(5)
print(f"scalar: {scalar}")
print(f"scalar.ndim: {scalar.ndim}")
print(f"scalar.shape: {scalar.shape}")
print("=" * 50)

# Vector = 1D Tensor
vector = torch.tensor([1,2,3])
print(f"vector: {vector}")
print(f"vector.ndim: {vector.ndim}")
print(f"vector.shape: {vector.shape}")
print("=" * 50)

# Matrix = 2D Tensor
matrix = torch.tensor([[1,2],[3,6]])
print(f"matrix: {matrix}")
print(f"matrix.ndim: {matrix.ndim}")
print(f"matrix.shape: {matrix.shape}")
print("=" * 50)

# Tensor = 3D Tensor
higher_dimensional_tensor = torch.randn(2,3,4)
print(f"higher dimensional tensor: {higher_dimensional_tensor}")
print(f"higher_dimensional_tensor.ndim: {higher_dimensional_tensor.ndim}")
print(f"higher_dimensional_tensor.shape: {higher_dimensional_tensor.shape}")
print("=" * 50)
# Out:
# scalar: 5
# scalar.ndim: 0
# scalar.shape: torch.Size([])
# ...
# vector: tensor([1, 2, 3])
# vector.ndim: 1
# vector.shape: torch.Size([3])
# ...
# matrix: tensor([[1, 2],
#         [3, 6]])
# matrix.ndim: 2
# matrix.shape: torch.Size([2, 2])
# ...
# higher dimensional tensor: tensor([[[ 0.7099,  0.1129, -1.5682,  0.2946],
#          [ 0.0241, -0.3307, -1.1887, -1.0140],
#          [-0.5272,  1.2910, -0.6481, -0.0987]],
#
#         [[-0.4990,  0.4531,  1.5164, -0.0053],
#          [ 1.3406, -1.4711,  0.7976, -0.2060],
#          [ 1.9956,  0.1079, -0.8228, -0.3741]]])
# higher_dimensional_tensor.ndim: 3
# higher_dimensional_tensor.shape: torch.Size([2, 3, 4])
# ...

# %% [markdown]
# # Creating Tensors in PyTorch
#
# we can create **tensors** using different methods:
#
# - **torch.tensor():** Create tensor from a Python list or number.
# - **torch.zeros():** Create tensor filled with zeros.
# - **torch.ones():** Create tensor filled with ones.
# - **torch.rand():** Create tensor filled with random numbers between 0 and 1.
#
# ---
#
# # Understanding Dimensions (Shape)
#
# - A **scalar** has **0 dimensions**: just a number.
# - A **vector** has **1 dimension**: a list of numbers.
# - A **matrix** has **2 dimensions**: rows and columns.
# - A **3D tensor** is like a stack of matrices.
#
#
#
# ---

# %% [markdown]
# # Basic Tensor Operations
#
# Tensors are not just storage for numbers — we also **perform operations** on them, like addition, multiplication, and matrix multiplication.
#
# Here are some basic operations you should know:
#
# ---
#
# # Element-wise Addition
#
# Given two vectors:
#
# $$
# \mathbf{a} = [1, 2, 3], \quad \mathbf{b} = [4, 5, 6]
# $$
#
# Element-wise addition:
#
# $$
# \mathbf{a} + \mathbf{b} = [1+4, 2+5, 3+6] = [5, 7, 9]
# $$
#
# ---
#
# # Element-wise Multiplication
#
# Element-wise multiplication (also called Hadamard product):
#
# $$
# \mathbf{a} \circ \mathbf{b} = [1 \times 4, 2 \times 5, 3 \times 6] = [4, 10, 18]
# $$
#
# ---
#
# # Dot Product (Inner Product)
#
# The dot product of two vectors:
#
# $$
# \text{dot}(\mathbf{a}, \mathbf{b}) = (1 \times 4) + (2 \times 5) + (3 \times 6) = 4 + 10 + 18 = 32
# $$
#
# ---
#
# # Matrix Multiplication
#
# Given two matrices:
#
# $$
# \mathbf{A} = \begin{bmatrix} 1 & 2 \\ 3 & 4 \end{bmatrix}, \quad
# \mathbf{B} = \begin{bmatrix} 5 & 6 \\ 7 & 8 \end{bmatrix}
# $$
#
# Matrix multiplication:
#
# $$
# \mathbf{A} \times \mathbf{B} =
# \begin{bmatrix}
# 1 \cdot 5 + 2 \cdot 7 & 1 \cdot 6 + 2 \cdot 8 \\
# 3 \cdot 5 + 4 \cdot 7 & 3 \cdot 6 + 4 \cdot 8
# \end{bmatrix}
# =
# \begin{bmatrix}
# 19 & 22 \\
# 43 & 50
# \end{bmatrix}
# $$
#
# ---
#
# **Tensor operations** allow deep learning models to process inputs, update weights, and make predictions.

# %%
a = torch.tensor([1, 2, 3])
b = torch.tensor([4, 5, 6])

# Element Wise Addition
print("Element Wise Addition")
print(a + b)
print("=" * 50)

# Element Wise Multiplication
print("Element Wise Multiplication")
print(a * b)
print("=" * 50)

# Dot Product
print("Dot Product")
print(torch.dot(a, b))
print("=" * 50)
# Out:
# Element Wise Addition
# tensor([5, 7, 9])
# ...
# Element Wise Multiplication
# tensor([ 4, 10, 18])
# ...
# Dot Product
# tensor(32)
# ...

# %%
A = torch.tensor([[1, 2], [3, 4]])
B = torch.tensor([[5, 6], [7, 8]])

# Matrix Multiplication
print("Matrix Multiplication")
print(torch.matmul(A, B))
# Out:
# Matrix Multiplication
# tensor([[19, 22],
#         [43, 50]])

# %% [markdown]
# # Broadcasting
#
# **Broadcasting** is a powerful concept in PyTorch that allows tensors with **different shapes** to be combined automatically during operations.
#
# ---
#
# #### Example:
#
# Suppose we have:
#
# - A matrix $X$ of shape $(2, 3)$:
#
# $$
# X =
# \begin{bmatrix}
# 1 & 2 & 3 \\
# 4 & 5 & 6
# \end{bmatrix}
# $$
#
# - A vector $b$ of shape $(3,)$:
#
# $$
# b = [7, 8, 9]
# $$
#
# When we do:
#
# $$
# X + b
# $$
#
# The vector $b$ is **automatically expanded** (broadcasted) to match the shape of $X$.
#
# **Result:**
#
# $$
# \begin{bmatrix}
# 1+7 & 2+8 & 3+9 \\
# 4+7 & 5+8 & 6+9
# \end{bmatrix}
# =
# \begin{bmatrix}
# 8 & 10 & 12 \\
# 11 & 13 & 15
# \end{bmatrix}
# $$

# %%
X = torch.tensor([[1, 2, 3], [4, 5, 6]])
bias = torch.tensor([10, 20, 30])

print("Broadcasting Results", X + bias)
# Out:
# Broadcasting Results tensor([[11, 22, 33],
#         [14, 25, 36]])

# %% [markdown]
# # Linear Function: Foundation of Linear Models
#
# ## Task: Predict concrete compressive strength (MPa)
# 	​
# ### Process
#
#  Simple Equation of A Line: $y = \beta + \omega x$
#
#  | Column                        | ML role          | \(x_i\) |
# | ----------------------------- | ---------------- | ------: |
# | Cement                        | Feature          | $x_1\ $ |
# | Blast Furnace Slag            | Feature          | $x_1\ $ |
# | Fly Ash                       | Feature          | $x_1\ $ |
# | Water                         | Feature          | $x_1\ $ |
# | Superplasticizer              | Feature          | $x_1\ $ |
# | Coarse Aggregate              | Feature          | $x_1\ $ |
# | Fine Aggregate                | Feature          | $x_1\ $ |
# | Age                           | Feature          | $x_1\ $ |
# | Concrete compressive strength | **Target \(y\)** |   $y\ $ |
#
# ---
#
#
#
# The Linear Regression Becomes:
#
# $y=β+ω1​x1​+ω2​x2​+ω3​x3​+ω4​x4​+ω5​x5​+ω6​x6​+ω7​x7​+ω8​x8​\$
#
#
#
# Then linear regression learns:
#
#
# $$ \boxed{y=\beta+X\omega} $$
#
# where \(X\) contains 8 features and \(y\) is compressive strength.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# | Column | Role | Function in Concrete |
# | --- | --- | --- |
# | **[Cement (component 1)](ca://s?q=Cement_in_concrete_mixture)** | Input | Primary binder; reacts with water to form hardened paste. |
# | **[Blast Furnace Slag (component 2)](ca://s?q=Blast_furnace_slag_in_concrete)** | Input | Supplementary cementitious material; improves durability and sustainability. |
# | **[Fly Ash (component 3)](ca://s?q=Fly_ash_in_concrete_mixture)** | Input | Byproduct of coal combustion; enhances workability and reduces heat of hydration. |
# | **[Water (component 4)](ca://s?q=Water_in_concrete_mixture)** | Input | Essential for hydration; water-to-cement ratio strongly influences strength. |
# | **[Superplasticizer (component 5)](ca://s?q=Superplasticizer_in_concrete_mixture)** | Input | Chemical admixture; increases workability without extra water, enabling stronger concrete. |
# | **[Coarse Aggregate (component 6)](ca://s?q=Coarse_aggregate_in_concrete_mixture)** | Input | Larger stones/gravel; provide bulk and structural strength. |
# | **[Fine Aggregate (component 7)](ca://s?q=Fine_aggregate_in_concrete_mixture)** | Input | Sand/small particles; fill voids between coarse aggregates, improving density. |
# | **[Age (day)](ca://s?q=Concrete_age_in_days)** | Input (time variable) | Number of days since casting; strength increases with curing time. |
# | **[Concrete Compressive Strength (MPa)](ca://s?q=Concrete_compressive_strength)** | Output | Target variable; measures load capacity before failure. |

# %%
df = pd.read_csv("/content/drive/MyDrive/Concrete_Data.csv")
df.head(10)
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  \
# 0                                      540.0
# 1                                      540.0
# 2                                      332.5
# 3                                      332.5
# 4                                      198.6
# 5                                      266.0
# 6                                      380.0
# 7                                      380.0
# 8                                      266.0
# 9                                      475.0
#
#    Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                0.0
# 1                                                0.0
# 2                                              142.5
# 3                                              142.5
# 4                                              132.4
# 5                                              114.0
# 6                                               95.0
# ...

# %%
print("Dataset Shape:", df.shape)
print("=" * 50)
print("Dataset Column:", df.columns)
print("=" * 50)
print(df.isna().sum())
# Out:
# Dataset Shape: (1030, 9)
# ...
# Dataset Column: Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')
# ...
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# ...

# %%
rename_dict = {
    'Cement (component 1)(kg in a m^3 mixture)': 'cement',
    'Blast Furnace Slag (component 2)(kg in a m^3 mixture)': 'slag',
    'Fly Ash (component 3)(kg in a m^3 mixture)': 'fly_ash',
    'Water  (component 4)(kg in a m^3 mixture)': 'water',
    'Superplasticizer (component 5)(kg in a m^3 mixture)': 'superplasticizer',
    'Coarse Aggregate  (component 6)(kg in a m^3 mixture)': 'coarse_aggregate',
    'Fine Aggregate (component 7)(kg in a m^3 mixture)': 'fine_aggregate',
    'Age (day)': 'age',
    'Concrete compressive strength(MPa, megapascals) ': 'compressive_strength'
}


df.rename(columns=rename_dict, inplace=True)

# %%
df.to_csv('/content/drive/MyDrive/concrete_data_clean.csv', index=False)

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['compressive_strength'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Concrete Compressive Strength')
plt.xlabel('Concrete Compressive Strength (MPa)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['cement'], df['water'], alpha=0.5)
plt.title('Water vs. Concrete Compressive Strength')
plt.xlabel('Water (kg in a m^3 mixture)')
plt.ylabel('Concrete Compressive Strength (MPa)')
plt.show()

# %%
plt.scatter(df['age'], df['compressive_strength'], alpha=0.5)
plt.title('Age vs. Concrete Compressive Strength')
plt.xlabel('Age (Days)')
plt.ylabel('Concrete Compressive Strength (MPa')
# Out:
# Text(0, 0.5, 'Concrete Compressive Strength (MPa')

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))


sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5,
    vmin=-1,
    vmax=1
)

plt.title('Concrete Dataset Correlation Heatmap', fontsize=14, pad=15)
plt.tight_layout()


plt.show()

# %%
components = ['cement', 'slag', 'fly_ash', 'water', 'superplasticizer',
              'coarse_aggregate', 'fine_aggregate']

plt.figure(figsize=(12, 6))
sns.boxplot(data=df[components], palette="Set2")

plt.title('Distribution of Concrete Components', fontsize=14, pad=15)
plt.ylabel('Amount (kg in a m^3 mixture)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(
    df[components],
    corner=True,
    plot_kws={'alpha': 0.5, 's': 15},
    diag_kws={'bins': 20}
)

plt.suptitle('Pairplot of Input Features', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# # Regression Line Plots

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Cement vs Strength
sns.regplot(x='cement', y='compressive_strength', data=df,
            ax=axes[0], scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
axes[0].set_title('Cement vs. Compressive Strength')

# Water vs Strength
sns.regplot(x='water', y='compressive_strength', data=df,
            ax=axes[1], scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
axes[1].set_title('Water vs. Compressive Strength')

# Age vs Strength
sns.regplot(x='age', y='compressive_strength', data=df,
            ax=axes[2], scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
axes[2].set_title('Age vs. Compressive Strength')

plt.tight_layout()
plt.show()

# %%
df_sample = df[components].sample(50, random_state=42).reset_index(drop=True)


df_sample.plot(kind='bar', stacked=True, figsize=(14, 7), colormap='tab10')

plt.title('Mixture Proportions for 20 Random Concrete Samples', fontsize=14, pad=15)
plt.xlabel('Sample ID')
plt.ylabel('Total Weight (kg in a m^3 mixture)')


plt.legend(title='Components', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
